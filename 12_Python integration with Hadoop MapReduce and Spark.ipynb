# %% [markdown]
# # Python integration with Hadoop MapReduce and Spark

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Quick-Recap:-Need-for-Real-Time-Analytics" data-toc-modified-id="Quick-Recap:-Need-for-Real-Time-Analytics-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Quick Recap: Need for Real-Time Analytics</a></span><ul class="toc-item"><li><span><a href="#Disparity-in-Programming-Languages" data-toc-modified-id="Disparity-in-Programming-Languages-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Disparity in Programming Languages</a></span></li><li><span><a href="#Integrating-Python-with-Hadoop" data-toc-modified-id="Integrating-Python-with-Hadoop-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Integrating Python with Hadoop</a></span></li><li><span><a href="#Need-for-Big-Data-Solutions-in-Python" data-toc-modified-id="Need-for-Big-Data-Solutions-in-Python-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Need for Big Data Solutions in Python</a></span></li></ul></li><li><span><a href="#Hadoop:-Core-Components" data-toc-modified-id="Hadoop:-Core-Components-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Hadoop: Core Components</a></span><ul class="toc-item"><li><span><a href="#HDFS" data-toc-modified-id="HDFS-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>HDFS</a></span></li><li><span><a href="#MapReduce" data-toc-modified-id="MapReduce-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>MapReduce</a></span></li><li><span><a href="#Hadoop:-System-Architecture" data-toc-modified-id="Hadoop:-System-Architecture-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Hadoop: System Architecture</a></span></li></ul></li><li><span><a href="#MapReduce" data-toc-modified-id="MapReduce-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>MapReduce</a></span><ul class="toc-item"><li><span><a href="#MapReduce:-Mapper-and-Reducer" data-toc-modified-id="MapReduce:-Mapper-and-Reducer-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>MapReduce: Mapper and Reducer</a></span><ul class="toc-item"><li><span><a href="#Mapper" data-toc-modified-id="Mapper-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Mapper</a></span></li><li><span><a href="#Reducer" data-toc-modified-id="Reducer-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Reducer</a></span></li></ul></li></ul></li><li><span><a href="#Hadoop-Streaming:-Python-API-for-Hadoop" data-toc-modified-id="Hadoop-Streaming:-Python-API-for-Hadoop-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Hadoop Streaming: Python API for Hadoop</a></span><ul class="toc-item"><li><span><a href="#Mapper-in-Python" data-toc-modified-id="Mapper-in-Python-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Mapper in Python</a></span></li><li><span><a href="#Reducer-in-Python" data-toc-modified-id="Reducer-in-Python-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Reducer in Python</a></span></li><li><span><a href="#Setting-Up-Cloudera-QuickStart-Virtual-Machine" data-toc-modified-id="Setting-Up-Cloudera-QuickStart-Virtual-Machine-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Setting Up Cloudera QuickStart Virtual Machine</a></span><ul class="toc-item"><li><span><a href="#QuickStart-VM-Terminal" data-toc-modified-id="QuickStart-VM-Terminal-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>QuickStart VM Terminal</a></span></li><li><span><a href="#Demo-01:-Using-Hadoop-Streaming-for-Calculating-Word-Count" data-toc-modified-id="Demo-01:-Using-Hadoop-Streaming-for-Calculating-Word-Count-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Demo-01: Using Hadoop Streaming for Calculating Word Count</a></span></li></ul></li><li><span><a href="#MapReduce-Uses-Disk-I/O-Operations" data-toc-modified-id="MapReduce-Uses-Disk-I/O-Operations-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>MapReduce Uses Disk I/O Operations</a></span></li><li><span><a href="#Apache-Spark-Uses-In-Memory-Instead-of-Disk-I/O" data-toc-modified-id="Apache-Spark-Uses-In-Memory-Instead-of-Disk-I/O-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Apache Spark Uses In-Memory Instead of Disk I/O</a></span></li><li><span><a href="#Hardware-Requirements-for-MapReduce-and-Spark" data-toc-modified-id="Hardware-Requirements-for-MapReduce-and-Spark-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Hardware Requirements for MapReduce and Spark</a></span></li></ul></li><li><span><a href="#Apache-Spark-Resilient-Distributed-Systems-(RDD)" data-toc-modified-id="Apache-Spark-Resilient-Distributed-Systems-(RDD)-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Apache Spark Resilient Distributed Systems (RDD)</a></span><ul class="toc-item"><li><span><a href="#Advantages-of-Spark" data-toc-modified-id="Advantages-of-Spark-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Advantages of Spark</a></span></li><li><span><a href="#PySpark:-Python-API-for-Spark" data-toc-modified-id="PySpark:-Python-API-for-Spark-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>PySpark: Python API for Spark</a></span></li><li><span><a href="#PySpark:-RDD-Transformations-and-Actions" data-toc-modified-id="PySpark:-RDD-Transformations-and-Actions-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>PySpark: RDD Transformations and Actions</a></span></li></ul></li><li><span><a href="#Spark-Tools" data-toc-modified-id="Spark-Tools-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Spark Tools</a></span><ul class="toc-item"><li><span><a href="#Setting-Up-Apache-Spark" data-toc-modified-id="Setting-Up-Apache-Spark-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Setting Up Apache Spark</a></span></li><li><span><a href="#Setting-Up-Environmental-Variable-of-Apache-Spark" data-toc-modified-id="Setting-Up-Environmental-Variable-of-Apache-Spark-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Setting Up Environmental Variable of Apache Spark</a></span></li><li><span><a href="#Integrating-Jupyter-Notebook-with-Apache-Spark" data-toc-modified-id="Integrating-Jupyter-Notebook-with-Apache-Spark-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Integrating Jupyter Notebook with Apache Spark</a></span></li></ul></li><li><span><a href="#Demo---02:-Using-pyspark-determine-the-wordcount." data-toc-modified-id="Demo---02:-Using-pyspark-determine-the-wordcount.-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Demo - 02: Using pyspark determine the wordcount.</a></span></li></ul></div>

# %% [markdown]
# ## Quick Recap: Need for Real-Time Analytics
#
# We have seen how big data is generated and understood that to extract insights, proper analysis of data is more important than its size.
# ![hadoop1.PNG](attachment:hadoop1.PNG)
#
# Real-time analytics is the rage right now because it helps extract information from different data sources almost instantly.

# %% [markdown]
# ![hadoop2.PNG](attachment:hadoop2.PNG)

# %% [markdown]
# ![hadoop3.PNG](attachment:hadoop3.PNG)

# %% [markdown]
# Data Scientists all over the world prefer Python because it is an easy-to-use language that has diverse libraries required for analytics.
# ![hadoop4.PNG](attachment:hadoop4.PNG)

# %% [markdown]
# ### Disparity in Programming Languages
# However, Big Data can only be accessed through Hadoop which is completely developed and implemented in Java. Also, analytics platforms are coded in different programming languages.
# ![hadoop5.PNG](attachment:hadoop5.PNG)

# %% [markdown]
# ### Integrating Python with Hadoop
# As Python is a Data Scientist’s first language of choice, both Hadoop and Spark provide Python APIs that allow easy access to the Big Data platform.
#
# ![hadoop6.PNG](attachment:hadoop6.PNG)

# %% [markdown]
# ### Need for Big Data Solutions in Python
# Need for Big Data Solutions in PythonThere are several reasons for creating Big Data solutions in Python.
# ![hadoop7-2.PNG](attachment:hadoop7-2.PNG)

# %% [markdown]
# ## Hadoop: Core Components
# 1. HDFS(Hadoop Distributed File Systems)
# 2. Hadoop MapReduce
#
# ### HDFS
# * It is responsible for storing data on a cluster.
# * Data is split into blocks and distributed across multiple nodes in a cluster.
# * Each block is replicated multiple times.
#     * Default is 3 times.
#     * Replicas are stored on different nodes.
#
# ### MapReduce
# * MapReduce is a data processing framework to process data on the cluster.
# * Two consecutive phases: Map and Reduce.
# * Each map task operates on discrete portions of data.
# * After map, reduce works on the intermediate data distributed on nodes
#
# ### Hadoop: System Architecture
# This example illustrates the Hadoop system architecture and the ways to store data in a cluster.
# ![mapreduce1.PNG](attachment:mapreduce1.PNG)

# %% [markdown]
# ## MapReduce
# The second core component of Hadoop is MapReduce, the primary framework of the HDFS architecture.
# ![mapreduce2.PNG](attachment:mapreduce2.PNG)

# %% [markdown]
# ### MapReduce: Mapper and Reducer
# Let us discuss the MapReduce functions, mapper and reducer, in detail.
#
# #### Mapper
# * Mappers run locally on the data nodes to avoid the network traffic.
# * Multiple mappers run in parallel processing a portion of the input data.
# * The mapper reads data in the form of key-value pairs.
# * If the mapper write generates an output, it is written in the form of key-value pairs.
#
# #### Reducer
# * All intermediate values for a given intermediate key are combined together into a list and given to a reducer.
# * This step is known as shuffleand sort.
# * The reducer outputs either zero or more final key-value pairs. These are written to HDFS.

# %% [markdown]
# ## Hadoop Streaming: Python API for Hadoop
# Hadoop Streaming acts like a bridge between your Python code and the Java-based HDFS, and lets you seamlessly access Hadoop clusters and execute MapReduce tasks.
# ![mapreduce3.PNG](attachment:mapreduce3.PNG)

# %% [markdown]
# ### Mapper in Python
# Python supports map and reduce operations:
# ![mapreduce4.PNG](attachment:mapreduce4.PNG)

# %% [markdown]
# ### Reducer in Python
# ![mapreduce5.PNG](attachment:mapreduce5.PNG)

# %% [markdown]
# ### Setting Up Cloudera QuickStart Virtual Machine
# * Install Virtual Machine
# * Download the image file of cloudera latest os
# * mount the file in Virtual machine
#
# #### QuickStart VM Terminal
# Unix command :
# * __pwd__ to verify present working directory.
# * __ls -lrt__ to list files and directories.
#
# #### Demo-01: Using Hadoop Streaming for Calculating Word Count
# Demonstrate how to create a MapReduce program and use Hadoop Streaming to determine the word count of a document.
#
# __Refer the "Hadoop_MapReduce_WordCount.txt" file for the commands to calculate the word count and its results.__

# %% [markdown]
# ### MapReduce Uses Disk I/O Operations
# ![mapIo1.PNG](attachment:mapIo1.PNG)

# %% [markdown]
# ### Apache Spark Uses In-Memory Instead of Disk I/O
# ![mapIo2.PNG](attachment:mapIo2.PNG)

# %% [markdown]
# ### Hardware Requirements for MapReduce and Spark
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Apache Spark Resilient Distributed Systems (RDD)
# Some basic concepts about Resilient Distributed Datasets (RDD) are:
#
# * The main programming approach of Spark is RDD.
# * They are fault-tolerant collections of objects spread across a cluster that you can operate on in parallel. They can automatically recover from machine failure.
# * You can create an RDD either by copying the elements from an existing collection or by referencing a dataset stored externally.
# * RDDs support two types of operations: transformations and actions.
#     * Transformations use an existing dataset to create a new one.
#         * Example: Map, filter, join
#     * Actions compute on the dataset and return the value to the driver program.
#         * Example: Reduce, count, collect, save
#
# __If the available memory is insufficient, then the data is written to disk.__

# %% [markdown]
# ### Advantages of Spark
# 1. __Faster:__ 10 to 100 times faster than Hadoop MapReduce.
# 2. __Simplified:__
#     * Simple data processing framework.
#     * Interactive APIs for Python for faster application  development
# 3. __Efficient:__ Has multiple tools for complex analytics operations
# 4. __Integrated:__ Can be easily integrated with existing Hadoop infrastructure.
#
# ### PySpark: Python API for Spark
# PySpark is the Spark Python API which enables data scientists to access Spark programming model.
#
# ![pyspark1.PNG](attachment:pyspark1.PNG)

# %% [markdown]
# ### PySpark: RDD Transformations and Actions
# ![pyspark2.PNG](attachment:pyspark2.PNG)
#
# __SparkContext or SC__ is the entry point to spark for the spark application.

# %% [markdown]
# ## Spark Tools
# ![pyspark3.PNG](attachment:pyspark3.PNG)

# %% [markdown]
# ### Setting Up Apache Spark
# To set up the Apache Spark environment, access the link:
# http://spark.apache.org/downloads.html
#
# Please use7-Zipto extract these files amd install.

# %% [markdown]
# ### Setting Up Environmental Variable of Apache Spark
# ![pyspark4.PNG](attachment:pyspark4.PNG)

# %% [markdown]
# ### Integrating Jupyter Notebook with Apache Spark
# ![pyspark5.PNG](attachment:pyspark5.PNG)

# %% [markdown]
# * Before Starting the 'pyspark'.
# * Close the terminal.
# * Close any active notebook sessions.
# * open the terminal and type 'pyspark', a new notebook session will start.

# %%
sc
# Out:
# <SparkContext master=local[*] appName=PySparkShell>

# %% [markdown]
# ## Demo - 02: Using pyspark determine the wordcount.

# %%
#Create an RDD, load the dataset with textfile method.
text_data_file = sc.textFile('D:\\NIPUN_SC_REC\\3_Practice_Project\\Course_5_Data Science with Python\\Lesson_recap\\yelp_labelled.txt')

#import the required library for word count operation.
from operator import add

#use filter to return RDD for words length greater than zero
wordcountFilter = text_data_file.filter(lambda X: len(X)>0)

#Verify the word count
wordcountFilter.count()
# Out:
# 1000

# %%
#use flat map to split each line into words
wordFlatmap = wordcountFilter.flatMap(lambda X:X.split())

#map each key with value 1 using MapReduce
wordMapper = wordFlatmap.map(lambda X:(X,"10_Data Visualization in Python using matplotlib.ipynb"))

#use reduceByKey function to reduce above mapped keys.
#returns the key value pairs by adding values for simillar keys
wordCount = wordMapper.reduceByKey(add)

#view the first element
wordCount.first()
# Out:
# ('Loved',
#  '10_Data Visualization in Python using matplotlib.ipynb10_Data Visualization in Python using matplotlib.ipynb')

# %%
wordCount.take(50)
# Out:
# [('Loved',
#   '10_Data Visualization in Python using matplotlib.ipynb10_Data Visualization in Python using matplotlib.ipynb'),
#  ('this',
# ...

# %%
wordCount.collect()
# Out:
# [('Loved',
#   '10_Data Visualization in Python using matplotlib.ipynb10_Data Visualization in Python using matplotlib.ipynb'),
#  ('this',
# ...
